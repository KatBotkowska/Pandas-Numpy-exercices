# %% [markdown]
# <a href="https://colab.research.google.com/github/KatBotkowska/Pandas-Numpy-exercices/blob/master/Warsztaty_WIT_2_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **WARSZTAT NR 2**

# %% [markdown]
# ## **Numpy**
# Podstawowy pakiet Pythona do obsługi macierzy i wektorów. Macierz 'ndarray' z tego pakietu jest dużo bardziej efektywnym sposobem przechowywania i pracy z danymi numerycznymi niż domyślne struktury Pythona.
# - NumPy jest szybki
# - korzysta się z niego głównie do zastosowań matematycznych i naukowych
# - wprowadza broadcasting
#
# W uczeniu maszynowym często wykonujemy operacje na macierzach (wektor to też przykład macierzy, tylko że jeden z wymiarów wynosi 1). Chcemy takie operacje wykonywać, gdzie tylko się da przy pomocy funkcji z modułu numpy, bo tak jest efektywniej!
#
# Matematyka jest bezlitosna. Istnieją pewne określone reguły, określające warunki kiedy na macierzach można wykonywać operacje:
#
# aby dodać do siebie macierze/wektory, muszą one mieć takie same wymiary
# aby pomnożyć przez siebie dwie macierze, pierwsza z nich musi  mieć tyle kolumn, co druga wierszy
# Tymczasem u nas te warunki nie zawsze będą spełnione. Można się jednak „umówić”, co do tego jak wykonywać operacje, których, matematycznie rzecz ujmując, nie można wykonywać. Taki mechanizm w NumPy nosi nazwę broadcasting, bo określa on, jak należy powiększyć mniejszą macierz do rozmiarów pasujących do większej macierzy, aby w intuicyjny sposób wykonać operację na macierzach.
#
# Żeby uniknąć matematycznego hejtu, na usprawiedliwienie należy dodać, że broadcasting-u można by uniknąć. W takim przypadku programista musiałby po prostu samodzielnie dbać o to, żeby macierze miały właściwe rozmiary. Taka praca, nie dość że nudna, to jeszcze spowoduje znaczne użycie pamięci. Dlatego tak się palimy do zautomatyzowanego i zoptymalizowanego procesu broadcastu.
#
#
# Cheatsheet: https://www.hb.ucsc.edu/wp-content/uploads/2017/09/numpy.pdf
# Więcej: https://numpy.org/doc/stable/user/whatisnumpy.html

# %%
import numpy as np # algebra

seq=[1,2,3]
x = np.array(seq)

# %%
#jako obiekt ndarray ma listę możliwych metod
x.sort()
x
# Out:
# array([1, 2, 3])

# %%
a = np.array([1, 2, 3])
b = np.array([10,20,30])
a, b
# Out:
# (array([1, 2, 3]), array([10, 20, 30]))

# %%
a+b
# Out:
# array([11, 22, 33])

# %%
a = np.array([1, 2, 3])
c = 100
a,c
# Out:
# (array([1, 2, 3]), 100)

# %%
# broadcasting: jeśli masz do wykonania operację na dwóch tablicach (wektorach) i jeden z nich jest dłuższy od drugiego, to ten drugi „poszerzamy” powtarzając jego wartość.
a+c
# Out:
# array([101, 102, 103])

# %% [markdown]
# ## **Pandas**
# Najważniejszy pakiet dla analityka danych!
#
# Cheatsheet Pandas basics: http://datacamp-community-prod.s3.amazonaws.com/dbed353d-2757-4617-8206-8767ab379ab3
#
# Cheatsheet Pandas data wrangling: https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
#
#
# Z Pandas przejdziemy wszystkie **etapy pracy z danymi**:
#
# 1. Import danych
#
# 2. Ekspolorowanie ('oglądanie') danych
#
# 3. Wybieranie/wycinanie potrzebnych do analizy danych (ich podzbioru)
#
# 4. Czyszczenie danych - uzupełnianie braków danych, wyrzucanie obserwacji odstających, zmiana nazw i typu danych
#
# 5. 'Manipulacja' danymi - sortowanie, grupowanie, flitrowanie
#
# 6. Łączenie różnych zbiorów danych
#
# 7. Ewentualnie - modelowanie lub użycie metod ML
#
# 8. Zapis danych

# %%
import pandas as pd # przetwarzanie danych, CSV file I/O (i.e. pd.read_csv)

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# W Pandas pracujemy na typie danych Data Frame, który składa się z Series.

# %%
#podłączenie google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data = pd.read_csv('/content/gdrive/MyDrive/WiT_workshops/[datasets]/PRSA_Data_Aotizhongxin_20130301-20170228.csv')

# %%
#data = pd.read_csv('PLIKI/Untitled Folder/PRSA_Data_Aotizhongxin_20130301-20170228.csv', sep=',')

# %%
data
# Out:
#           No  year  month  day  hour  ...  DEWP  RAIN   wd  WSPM       station
# 0          1  2013      3    1     0  ... -18.8   0.0  NNW   4.4  Aotizhongxin
# 1          2  2013      3    1     1  ... -18.2   0.0    N   4.7  Aotizhongxin
# 2          3  2013      3    1     2  ... -18.2   0.0  NNW   5.6  Aotizhongxin
# 3          4  2013      3    1     3  ... -19.4   0.0   NW   3.1  Aotizhongxin
# 4          5  2013      3    1     4  ... -19.5   0.0    N   2.0  Aotizhongxin
# ...      ...   ...    ...  ...   ...  ...   ...   ...  ...   ...           ...
# 35059  35060  2017      2   28    19  ... -16.2   0.0   NW   2.4  Aotizhongxin
# 35060  35061  2017      2   28    20  ... -15.1   0.0  WNW   0.9  Aotizhongxin
# 35061  35062  2017      2   28    21  ... -13.3   0.0   NW   1.1  Aotizhongxin
# 35062  35063  2017      2   28    22  ... -12.9   0.0  NNW   1.2  Aotizhongxin
# 35063  35064  2017      2   28    23  ... -15.9   0.0  NNE   1.3  Aotizhongxin
#
# ...

# %%
#wyświetlamy nazwy kolumn
data.columns
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2',
#        'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station'],
#       dtype='object')

# %%
#do kolumn możemy odwołać się przez kropkę po nazwie Data Frame (df)
#każdy df posiada nazwy kolumn oraz indeks (nazwy wierszy) - tworzony automatycznie, ma wartości od zera wzwyż.
data.month
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
#         ..
# 35059    2
# 35060    2
# 35061    2
# 35062    2
# 35063    2
# Name: month, Length: 35064, dtype: int64

# %%
#index to range - można po nim iterować
#for ind in data.index: 
#     print(data.month) 
data.index
# Out:
# RangeIndex(start=0, stop=35064, step=1)

# %%
#obejrzyjmy typy danych
#stringi to objects w Pythonie
data.dtypes
# Out:
# No           int64
# year         int64
# month        int64
# day          int64
# hour         int64
# PM2.5      float64
# PM10       float64
# SO2        float64
# NO2        float64
# CO         float64
# O3         float64
# TEMP       float64
# PRES       float64
# DEWP       float64
# RAIN       float64
# wd          object
# WSPM       float64
# station     object
# dtype: object

# %%
data.shape
# Out:
# (35064, 18)

# %%
#podstawowe statystyki opisowe
data.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
 #ile pustych danych (nulli) mamy w tabeli?
data.isnull().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
#musimy coś zrobić z brakami danych - najprościej uzupełnić je zerami
#data = data.fillna(0)
#ale to może powodować problemy z interpretacją
#spróbujmy inaczej
data['PM10'].fillna(data['PM10'].median(), inplace=True)
data['SO2'].fillna(data['SO2'].median(), inplace=True)
data['NO2'].fillna(data['NO2'].mean(), inplace=True)
data['CO'].fillna(data['CO'].median(), inplace=True)
data['O3'].fillna(data['O3'].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5      925
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP        20
# PRES        20
# DEWP        20
# RAIN        20
# wd          81
# WSPM        14
# station      0
# dtype: int64

# %%
#nazwa WSPM jest nieintuicyjna - zmieńmy ją na wind_speed
data.rename({'WSPM': 'wind_speed'}, axis=1, inplace=True) #inplace - modyfikujemy obiekt i nic nie zwracamy; bez tego tworzymy kopię
data
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  wind_speed       station
# ...

# %%
#sortowanie danych
data.sort_values('year',ascending=False)
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2   NO2     CO    O3  \
# 35063  35064  2017      2   28    23   19.0   31.0  10.0  79.0  600.0  42.0
# 34090  34091  2017      1   19    10   34.0  114.0  18.0  27.0  700.0  50.0
# 34114  34115  2017      1   20    10   16.0   25.0  11.0  37.0  700.0  49.0
# 34115  34116  2017      1   20    11   17.0   26.0   9.0  35.0  700.0  53.0
# 34116  34117  2017      1   20    12   21.0   21.0   9.0  33.0  700.0  57.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...   ...    ...   ...
# 4900    4901  2013      9   21     4   29.0   50.0   8.0  56.0  200.0   1.0
# 4901    4902  2013      9   21     5   22.0   50.0   5.0  54.0  300.0   1.0
# 4902    4903  2013      9   21     6   21.0   31.0   5.0  55.0  300.0   1.0
# 4903    4904  2013      9   21     7   25.0   70.0   5.0  55.0  300.0   1.0
# 0          1  2013      3    1     0    4.0    4.0   4.0   7.0  300.0  77.0
#
# ...

# %%
#grupowanie danych - bardzo przydatne i często wykorzystywane w analizie danych
#przyglądając się konkretnym pozbiorom możemy się więcej dowiedzieć - np.: pogrupować dane sprzedaży po numerze kupującego albo po kategorii produktów
data.groupby('year').describe().PM10 #czyli pogrupuj dane po roku, wypisz statystyki opisowe - i żeby tabelka nie była za duża, na razie pokaż to tylko dla kolumny PM10
# Out:
#        count        mean         std  min     25%   50%     75%    max
# year
# 2013  7344.0  112.897467   84.447315  2.0  47.000  97.0  156.00  844.0
# 2014  8760.0  120.107911   98.023920  3.0  47.000  92.0  165.00  948.0
# 2015  8760.0  111.772135   99.531673  3.0  36.675  87.0  158.00  984.0
# 2016  8784.0   94.551343   86.532509  4.0  33.000  71.0  126.00  884.0
# 2017  1416.0  107.113701  117.820690  3.0  24.000  67.0  148.25  858.0

# %%
#możemy też grupować po dwóch zmiennych
data.groupby(['year','month']).describe()
# Out:
#                No                                                             \
#             count     mean         std      min       25%      50%       75%
# year month
# 2013 3      744.0    372.5  214.918589      1.0    186.75    372.5    558.25
#      4      720.0   1104.5  207.990384    745.0    924.75   1104.5   1284.25
#      5      744.0   1836.5  214.918589   1465.0   1650.75   1836.5   2022.25
#      6      720.0   2568.5  207.990384   2209.0   2388.75   2568.5   2748.25
#      7      744.0   3300.5  214.918589   2929.0   3114.75   3300.5   3486.25
#      8      744.0   4044.5  214.918589   3673.0   3858.75   4044.5   4230.25
#      9      720.0   4776.5  207.990384   4417.0   4596.75   4776.5   4956.25
#      10     744.0   5508.5  214.918589   5137.0   5322.75   5508.5   5694.25
#      11     720.0   6240.5  207.990384   5881.0   6060.75   6240.5   6420.25
#      12     744.0   6972.5  214.918589   6601.0   6786.75   6972.5   7158.25
# ...

# %% [markdown]
# W ostatnim przykładzie widzimy przykład multiindeksów w Pandasie. W praktyce możemy mieć kilka kolumn, gdzie pojedyncza "kolumna" (a tak naprawdę grupa kolumn) jest również całym DataFramem.
#
# Posiadanie multiindeksu może być przydatne, ale zdecydowanie nie zawsze tak jest. Na szczęście w prosty sposób możemy się pozbyć jednego niepotrzebnego poziomu. Możemy to zrobić zarówno dla kolumn jak i dla wierszy. W przypadku kolumn nie jest to jednak oczywiste jak pozbyć się multiindeksu, tak aby nie tracić informacji. Skasowanie jednego poziomu nie będzie dla nas bardzo przydatne. Możemy więc np skleić nazwy obu 'poziomów' w jeden jak poniżej.
#
# Druga rzecz, która może być bardzo (nie)przydatna to multiindeks na wierszach. Czasami/często lepiej mieć po prostu wartości jako kolumny a nie indeks. Pozwoli nam to np na łatwe dalsze operacje (np pivotowanie).
#
# Więcej dla zainteresowanych:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html

# %%
#Poprawiamy multiindeksy:
data2 = data.groupby(['year','month']).describe() 
# Zmieńmy nazwy kolumn
data2.columns =  [x+y.capitalize() for x,y in data2.columns.values]
# Zresetujmy indeks wierszowy
data2.reset_index(inplace=True)
# Wyświetlmy kilka pierwszych obserwacji
data2.sample(10)
# Out:
#     year  month  NoCount   NoMean       NoStd    NoMin     No25%    No50%  \
# 41  2016      8    744.0  30348.5  214.918589  29977.0  30162.75  30348.5
# 2   2013      5    744.0   1836.5  214.918589   1465.0   1650.75   1836.5
# 29  2015      8    744.0  21564.5  214.918589  21193.0  21378.75  21564.5
# 15  2014      6    720.0  11328.5  207.990384  10969.0  11148.75  11328.5
# 45  2016     12    744.0  33276.5  214.918589  32905.0  33090.75  33276.5
# 11  2014      2    672.0   8424.5  194.133974   8089.0   8256.75   8424.5
# 6   2013      9    720.0   4776.5  207.990384   4417.0   4596.75   4776.5
# 43  2016     10    744.0  31812.5  214.918589  31441.0  31626.75  31812.5
# 35  2016      2    696.0  25956.5  201.062179  25609.0  25782.75  25956.5
# 20  2014     11    720.0  15000.5  207.990384  14641.0  14820.75  15000.5
#
#        No75%    NoMax  ...  RAIN75%  RAINMax  wind_speedCount  wind_speedMean  \
# ...

# %% [markdown]
# Powyżej skorzystaliśmy z jednolinijowej pętli for - bardzo popularnej rzeczy w analizie danych
# więcej na ten temat: https://blog.teamtreehouse.com/python-single-line-loops

# %%
# filtrowanie danych - gdy chcemy się przyjrzeć tylko części zbioru
#funkcja filter vs funkcja query
data.filter(items =['day','hour']).describe() #wybierz kolumny
# Out:
#                 day          hour
# count  35064.000000  35064.000000
# mean      15.729637     11.500000
# std        8.800218      6.922285
# min        1.000000      0.000000
# 25%        8.000000      5.750000
# 50%       16.000000     11.500000
# 75%       23.000000     17.250000
# max       31.000000     23.000000

# %%
data.query('PM10 > 100').describe().PM10 #wybierz wiersze, które spełniają zadany warunek i na nich wykonaj operacje
# Out:
# count    14996.000000
# mean       191.779154
# std         89.063047
# min        101.000000
# 25%        129.000000
# 50%        166.000000
# 75%        226.000000
# max        984.000000
# Name: PM10, dtype: float64

# %%
#sprawdzamy unikatowe wartości kolumny
#dlaczego year.unique() a nie odwrotnie? bo unique to metoda stosowana do serii, a nie df
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.unique.html
data.year.unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017])

# %%
#wybierz tylko wiersz o indeksie 2
data.loc[2]
# Out:
# No                       3
# year                  2013
# month                    3
# day                      1
# hour                     2
# PM2.5                    7
# PM10                     7
# SO2                      5
# NO2                     10
# CO                     300
# O3                      73
# TEMP                  -1.1
# PRES                1023.5
# DEWP                 -18.2
# RAIN                     0
# wd                     NNW
# wind_speed             5.6
# station       Aotizhongxin
# Name: 2, dtype: object

# %%
#wybierz tylko wiersz do indeksu 2 włącznie
data.loc[0:2]  
#jest jeszcze iloc: dla ciekawych
#https://stackoverflow.com/questions/31593201/how-are-iloc-and-loc-different
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0  4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0  5.0  10.0  300.0  73.0  -1.1
#
#      PRES  DEWP  RAIN   wd  wind_speed       station
# 0  1023.0 -18.8   0.0  NNW         4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N         4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW         5.6  Aotizhongxin

# %% [markdown]
# ### **Melt i pivot - zmiana struktury tabeli**
#
# Funkcja melt służy do zamiany formy szerokiej na długą. Pewne kolumny mają stopnieć i zasilić informacją wiersze.
# Pivot pozwala tworzyć tabele przestawne znane z MS Excel.

# %%
dataMelt = data.melt(id_vars=['year', 'month', 'day'])
dataMelt.sample(10)
# Out:
#         year  month  day    variable value
# 171388  2016      9   18         SO2     2
# 326478  2014      5   29        PRES   992
# 385141  2017      2    5        DEWP -17.8
# 386637  2013      4    8        RAIN     0
# 98195   2016      5   13       PM2.5    28
# 387836  2013      5   28        RAIN     0
# 199552  2015     12    5         NO2    49
# 379983  2016      7    5        DEWP  17.2
# 468005  2014      7   21  wind_speed   2.9
# 116119  2014      5   30        PM10    49

# %%
dataPivot = data.pivot_table(values='PM10', index='month', columns='year', aggfunc=pd.Series.nunique)
dataPivot
# Out:
# year    2013   2014   2015   2016   2017
# month
# 1        NaN  283.0  264.0  225.0  292.0
# 2        NaN  298.0  268.0  167.0  227.0
# 3      308.0  301.0  311.0  304.0    NaN
# 4      230.0  248.0  271.0  248.0    NaN
# 5      254.0  294.0  233.0  181.0    NaN
# 6      266.0  163.0  210.0  171.0    NaN
# 7      190.0  227.0  187.0  173.0    NaN
# 8      194.0  205.0  187.0  126.0    NaN
# 9      232.0  213.0  197.0  184.0    NaN
# 10     255.0  337.0  251.0  236.0    NaN
# 11     246.0  303.0  278.0  287.0    NaN
# 12     261.0  187.0  339.0  302.0    NaN

# %% [markdown]
# ### **Łączenie tabel**

# %%
#Pobierzmy drugi set dotyczący innej stacji
data_2 = pd.read_csv('PLIKI/Untitled Folder/PRSA_Data_Changping_20130301-20170228.csv', sep=',')

# %%
#Gdybyśmy chcieli pobrać dane z linku - też można
import io
import requests
url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
c.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %%
data_full = data.append(data_2) # dopisuje wiersze drugiej tabeli poniżej, gdy kolumny są identyczne
data_full
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   28.0  47.0   4.0  14.0  300.0   NaN
# 35060  35061  2017      2   28    20   12.0  12.0   3.0  23.0  500.0  64.0
# 35061  35062  2017      2   28    21    7.0  23.0   5.0  17.0  500.0  68.0
# 35062  35063  2017      2   28    22   11.0  20.0   3.0  15.0  500.0  72.0
# 35063  35064  2017      2   28    23   20.0  25.0   6.0  28.0  900.0  54.0
#
#        TEMP    PRES  DEWP  RAIN   wd  wind_speed       station  WSPM
# ...

# %%
df1= data[['year','TEMP']]
df2= data_2[['year','TEMP']]

# %%
#tu mamy problem
df1.join(df2,on='year',how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-3e5eba8e7a3d> in <module>
#       1 #tu mamy problem
# ----> 2 df1.join(df2,on='year',how='left')
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7207         """
#    7208         return self._join_compat(
# -> 7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#    7211
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7230                 right_index=True,
#    7231                 suffixes=(lsuffix, rsuffix),
# -> 7232                 sort=sort,
#    7233             )
#    7234         else:
#
# ...

# %%
#potrzebny jest sufiks
df1.join(df2,on='year',how='left', lsuffix='_left', rsuffix='_right')
# Out:
#        year_left  TEMP_left  year_right  TEMP_right
# 0           2013       -0.7        2013        24.4
# 1           2013       -1.1        2013        24.4
# 2           2013       -1.1        2013        24.4
# 3           2013       -1.4        2013        24.4
# 4           2013       -2.0        2013        24.4
# ...          ...        ...         ...         ...
# 35059       2017       12.5        2013        21.6
# 35060       2017       11.6        2013        21.6
# 35061       2017       10.8        2013        21.6
# 35062       2017       10.5        2013        21.6
# 35063       2017        8.6        2013        21.6
#
# [35064 rows x 4 columns]

# %% [markdown]
# ### **Funkcje**

# %%
funkcja1 = lambda x: x*2
data_2.TEMP.apply(funkcja1)
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html
# Out:
# 0        -4.6
# 1        -5.0
# 2        -6.0
# 3        -7.2
# 4        -7.0
#          ...
# 35059    23.4
# 35060    21.8
# 35061    19.0
# 35062    15.6
# 35063    14.0
# Name: TEMP, Length: 35064, dtype: float64

# %%
#dla całej df - applymap
data_2.applymap(funkcja1)
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.applymap.html
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO     O3  \
# 0          2  4026      6    2     0    6.0  12.0  26.0  14.0   600.0  170.0
# 1          4  4026      6    2     2    6.0   6.0  12.0  12.0   600.0  170.0
# 2          6  4026      6    2     4    6.0   6.0  44.0  26.0   800.0  148.0
# 3          8  4026      6    2     6    6.0  12.0  24.0  16.0   600.0  162.0
# 4         10  4026      6    2     8    6.0   6.0  28.0  16.0   600.0  162.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...    ...
# 35059  70120  4034      4   56    38   56.0  94.0   8.0  28.0   600.0    NaN
# 35060  70122  4034      4   56    40   24.0  24.0   6.0  46.0  1000.0  128.0
# 35061  70124  4034      4   56    42   14.0  46.0  10.0  34.0  1000.0  136.0
# 35062  70126  4034      4   56    44   22.0  40.0   6.0  30.0  1000.0  144.0
# 35063  70128  4034      4   56    46   40.0  50.0  12.0  56.0  1800.0  108.0
#
# ...

# %%
data_full.groupby('station').describe().PM10
# Out:
#                 count        mean        std  min   25%   50%    75%    max
# station
# Aotizhongxin  35064.0  109.588187  94.299574  2.0  39.0  87.0  153.0  984.0
# Changping     34482.0   94.657871  83.441738  2.0  34.0  72.0  131.0  999.0

# %% [markdown]
# ### **Macierz korelacji**

# %%
corrMatrix = data.iloc[:,5:16].corr()
plt.figure(figsize = (16,5))
sns.heatmap(corrMatrix, annot=True)
plt.show()
